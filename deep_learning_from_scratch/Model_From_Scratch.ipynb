# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %%
# Download data

# %%
untar_data?

# %%
path = untar_data(URLs.IMAGEWOOF_320)
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-imageclas/imagewoof2-320

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/imagewoof2-320/val'),
#  PosixPath('/root/.fastai/data/imagewoof2-320/train')]

# %%
# Read data into dataloader

# %%
bs = 64

data = (ImageList.from_folder(path) 
        .split_by_folder(train='train', valid='val')             
        .label_from_folder()
        .transform(size = 320)
        .databunch(bs=bs)
        .normalize())

# %%
data.show_batch(3, 3, figsize=(8,8))

# %%
data.classes
# Out:
# ['n02086240',
#  'n02087394',
#  'n02088364',
#  'n02089973',
#  'n02093754',
#  'n02096294',
#  'n02099601',
#  'n02105641',
#  'n02111889',
#  'n02115641']

# %%
x,y = data.train_ds[0]

# %%
x.size
# Out:
# torch.Size([320, 320])

# %%
# Create Model

# %%
def conv(ni,nf): return nn.Conv2d(ni, nf, kernel_size=3, stride=2, padding=1)

# %%
model = nn.Sequential(
    conv(3, 8), # 14
    nn.BatchNorm2d(8),
    nn.ReLU(),
    conv(8, 16), # 7
    nn.BatchNorm2d(16),
    nn.ReLU(),
    conv(16, 32), # 4
    nn.BatchNorm2d(32),
    nn.ReLU(),
    conv(32, 64), # 2
    nn.BatchNorm2d(64),
    nn.ReLU(),
    conv(64, 128), # 2
    nn.BatchNorm2d(128),
    nn.ReLU(),
    conv(128, 64), # 2
    nn.BatchNorm2d(64),
    nn.ReLU(),
    conv(64, 32), # 2
    nn.BatchNorm2d(32),
    nn.ReLU(),
    conv(32, 16), # 2
    nn.BatchNorm2d(16),
    nn.ReLU(),
    conv(16, 10), # 1
    nn.BatchNorm2d(10),
    Flatten()     # remove (1,1) grid
)

# %%
# Create Learner

# %%
learn = Learner(data, model=model, loss_func = nn.CrossEntropyLoss(), metrics=accuracy)

# %%
print(learn.summary())
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [8, 160, 160]        224        True
# ______________________________________________________________________
# BatchNorm2d          [8, 160, 160]        16         True
# ______________________________________________________________________
# ReLU                 [8, 160, 160]        0          False
# ______________________________________________________________________
# Conv2d               [16, 80, 80]         1,168      True
# ______________________________________________________________________
# BatchNorm2d          [16, 80, 80]         32         True
# ______________________________________________________________________
# ReLU                 [16, 80, 80]         0          False
# ______________________________________________________________________
# Conv2d               [32, 40, 40]         4,640      True
# ______________________________________________________________________
# BatchNorm2d          [32, 40, 40]         64         True
# ______________________________________________________________________
# ReLU                 [32, 40, 40]         0          False
# ______________________________________________________________________
# Conv2d               [64, 20, 20]         18,496     True
# ______________________________________________________________________
# BatchNorm2d          [64, 20, 20]         128        True
# ______________________________________________________________________
# ReLU                 [64, 20, 20]         0          False
# ______________________________________________________________________
# Conv2d               [128, 10, 10]        73,856     True
# ______________________________________________________________________
# BatchNorm2d          [128, 10, 10]        256        True
# ______________________________________________________________________
# ReLU                 [128, 10, 10]        0          False
# ______________________________________________________________________
# Conv2d               [64, 5, 5]           73,792     True
# ______________________________________________________________________
# BatchNorm2d          [64, 5, 5]           128        True
# ______________________________________________________________________
# ReLU                 [64, 5, 5]           0          False
# ______________________________________________________________________
# Conv2d               [32, 3, 3]           18,464     True
# ______________________________________________________________________
# BatchNorm2d          [32, 3, 3]           64         True
# ______________________________________________________________________
# ReLU                 [32, 3, 3]           0          False
# ______________________________________________________________________
# Conv2d               [16, 2, 2]           4,624      True
# ______________________________________________________________________
# BatchNorm2d          [16, 2, 2]           32         True
# ______________________________________________________________________
# ReLU                 [16, 2, 2]           0          False
# ______________________________________________________________________
# Conv2d               [10, 1, 1]           1,450      True
# ______________________________________________________________________
# BatchNorm2d          [10, 1, 1]           20         True
# ______________________________________________________________________
# Flatten              [10]                 0          False
# ______________________________________________________________________
#
# Total params: 197,454
# Total trainable params: 197,454
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : CrossEntropyLoss
# ======================================================================
# Callbacks functions applied

# %%
learn.lr_find(end_lr=100)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='141' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       70.21% [99/141 00:24<00:10 3.1083]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(3, max_lr=3e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.697255</td>
#       <td>1.763314</td>
#       <td>0.385594</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.667579</td>
#       <td>1.730325</td>
#       <td>0.388139</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.618870</td>
#       <td>1.721107</td>
#       <td>0.392466</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Chance is higher than the random 10%
# Model is learning
# Fin
